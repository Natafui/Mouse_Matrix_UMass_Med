# %% [markdown]
# <h1><center>Evaluation Project</center></h1>
#
# UMass Chan Medical School
#
# Weng Lab
#
# Natalie Haas

# %% [markdown]
# First and foremost, the following libraries and tools must be imported.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
import math
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import re

# %% [markdown]
# A pandas tool is used to read in the dataset from the webpage provided.

# %%
df2 = pd.read_table("http://users.wenglab.org/moorej3/Yu-Project/Mouse-Enhancer-Matrix.txt")

# %%
df2
# Out:
#                ccres  C57BL/6_embryonic_facial_prominence_embryo_11.5_days  \
# 0       EM10D0024807                                           0.737987
# 1       EM10D0062280                                           0.737908
# 2       EM10D0073850                                           0.366271
# 3       EM10D0135775                                           0.531865
# 4       EM10D0156272                                           1.275800
# ...              ...                                                ...
# 209035  EM10D2262191                                           0.832552
# 209036  EM10D2262192                                           0.758047
# 209037  EM10D2262193                                           0.540201
# 209038  EM10D2262225                                           0.867886
# 209039  EM10D2262459                                           0.905531
#
#         C57BL/6_embryonic_facial_prominence_embryo_12.5_days  \
# 0                                                0.496333
# 1                                                0.756066
# 2                                                0.901060
# 3                                                0.987585
# 4                                                1.399650
# ...                                                   ...
# 209035                                           0.975463
# 209036                                           1.039910
# 209037                                           0.846094
# 209038                                           0.425700
# 209039                                           0.662782
#
#         C57BL/6_embryonic_facial_prominence_embryo_13.5_days  \
# 0                                                0.394944
# 1                                                0.619545
# 2                                                0.695672
# 3                                                0.451908
# 4                                                1.563410
# ...                                                   ...
# 209035                                           0.845471
# 209036                                           0.851552
# 209037                                           0.677188
# 209038                                           0.529801
# 209039                                           1.000810
#
#         C57BL/6_embryonic_facial_prominence_embryo_14.5_days  \
# 0                                                0.608239
# 1                                                0.840945
# 2                                                0.345374
# 3                                                0.425011
# 4                                                1.546810
# ...                                                   ...
# 209035                                           1.412510
# 209036                                           1.272120
# 209037                                           0.972213
# 209038                                           0.686463
# 209039                                           0.535091
#
#         C57BL/6_embryonic_facial_prominence_embryo_15.5_days  \
# 0                                                0.519169
# 1                                                0.786815
# 2                                                0.596921
# 3                                                0.790187
# 4                                                1.135640
# ...                                                   ...
# 209035                                           1.067880
# 209036                                           1.039310
# 209037                                           0.747629
# 209038                                           0.456390
# 209039                                           0.872270
#
#         C57BL/6_forebrain_embryo_11.5_days  \
# 0                                 0.476346
# 1                                 1.235750
# 2                                 1.018470
# 3                                 0.462021
# 4                                 1.296100
# ...                                    ...
# 209035                            1.494180
# 209036                            1.190560
# 209037                            0.804412
# 209038                            0.381875
# 209039                            0.716015
#
#         C57BL/6_forebrain_embryo_12.5_days  \
# 0                                 0.469204
# 1                                 1.365740
# 2                                 1.055840
# 3                                 0.838769
# 4                                 1.475620
# ...                                    ...
# 209035                            1.650460
# 209036                            1.520350
# 209037                            1.137400
# 209038                            0.742022
# 209039                            1.287840
#
#         C57BL/6_forebrain_embryo_13.5_days  \
# 0                                 0.728918
# 1                                 1.077090
# 2                                 0.776323
# 3                                 0.646874
# 4                                 1.383600
# ...                                    ...
# 209035                            1.402780
# 209036                            1.294210
# 209037                            0.961928
# 209038                            0.300008
# 209039                            1.290690
#
#         C57BL/6_forebrain_embryo_14.5_days  ...  \
# 0                                 0.526971  ...
# 1                                 0.811603  ...
# 2                                 0.829389  ...
# 3                                 0.505505  ...
# 4                                 1.491620  ...
# ...                                    ...  ...
# 209035                            1.261750  ...
# 209036                            1.016080  ...
# 209037                            0.751759  ...
# 209038                            0.306066  ...
# 209039                            0.705391  ...
#
#         C57BL/6_midbrain_postnatal_0_days  \
# 0                                0.651397
# 1                                0.935929
# 2                                0.645772
# 3                                0.386949
# 4                                1.653730
# ...                                   ...
# 209035                           0.862431
# 209036                           0.845303
# 209037                           0.710634
# 209038                           0.177244
# 209039                           0.340105
#
#         C57BL/6_neural_tube_embryo_11.5_days  \
# 0                                   0.531423
# 1                                   1.176740
# 2                                   0.855515
# 3                                   0.759358
# 4                                   1.861350
# ...                                      ...
# 209035                              0.991856
# 209036                              0.822021
# 209037                              0.594209
# 209038                              0.339435
# 209039                              0.670440
#
#         C57BL/6_neural_tube_embryo_12.5_days  \
# 0                                   0.782652
# 1                                   1.049060
# 2                                   0.890337
# 3                                   0.795779
# 4                                   0.979202
# ...                                      ...
# 209035                              0.891767
# 209036                              1.007000
# 209037                              0.761183
# 209038                              0.285803
# 209039                              0.618447
#
#         C57BL/6_neural_tube_embryo_13.5_days  \
# 0                                   0.606512
# 1                                   0.934667
# 2                                   0.610279
# 3                                   0.583168
# 4                                   1.484450
# ...                                      ...
# 209035                              1.587430
# 209036                              1.481420
# 209037                              1.127630
# 209038                              0.503609
# 209039                              1.045600
#
#         C57BL/6_neural_tube_embryo_14.5_days  \
# 0                                   0.465679
# 1                                   1.252420
# 2                                   0.783446
# 3                                   0.539668
# 4                                   1.591600
# ...                                      ...
# 209035                              1.243900
# 209036                              1.290480
# 209037                              0.987441
# 209038                              0.481451
# 209039                              0.686240
#
#         C57BL/6_neural_tube_embryo_15.5_days  \
# 0                                   0.559411
# 1                                   1.090870
# 2                                   0.673417
# 3                                   0.575424
# 4                                   1.638390
# ...                                      ...
# 209035                              1.353740
# 209036                              1.249030
# 209037                              0.847843
# 209038                              0.593258
# 209039                              0.672313
#
#         C57BL/6_stomach_embryo_14.5_days  C57BL/6_stomach_embryo_15.5_days  \
# 0                               0.489681                          0.728980
# 1                               0.949902                          0.745198
# 2                               0.752583                          0.868450
# 3                               0.840946                          0.597951
# 4                               1.287630                          1.074740
# ...                                  ...                               ...
# 209035                          1.026690                          1.098800
# 209036                          1.007790                          1.110660
# 209037                          0.754032                          0.825794
# 209038                          0.721343                          0.951221
# 209039                          0.223496                          0.880560
#
#         C57BL/6_stomach_embryo_16.5_days  C57BL/6_stomach_postnatal_0_days
# 0                               1.047850                          1.142360
# 1                               0.767133                          0.862137
# 2                               0.685157                          0.370126
# 3                               0.750593                          1.036590
# 4                               1.104080                          1.201430
# ...                                  ...                               ...
# 209035                          1.250270                          0.636807
# 209036                          1.247090                          0.647085
# 209037                          1.006760                          0.506143
# 209038                          0.879753                          0.728717
# 209039                          0.413285                          0.168914
#
# [209040 rows x 67 columns]

# %%
sample_names = df2.columns[1:]
matrix_values = df2.iloc[:,1:].values

# %%
df2_trans = np.log1p(matrix_values) #transforming

# %%
df2_trans
# Out:
# array([[0.55272755, 0.40301745, 0.33285427, ..., 0.54753164, 0.71679046,
#         0.76190803],
#        [0.55268209, 0.56307608, 0.48214525, ..., 0.55686802, 0.56935846,
#         0.62172475],
#        [0.31208513, 0.64241163, 0.52807912, ..., 0.62510921, 0.52185873,
#         0.31490271],
#        ...,
#        [0.43191293, 0.61307206, 0.51711858, ..., 0.60201496, 0.69652148,
#         0.40955208],
#        [0.62480731, 0.35466292, 0.42513766, ..., 0.66845533, 0.63114039,
#         0.54737951],
#        [0.64476071, 0.5084921 , 0.6935521 , ..., 0.6315696 , 0.34591678,
#         0.15607511]])

# %%
from sklearn.preprocessing import StandardScaler

matrix_values_normalized = StandardScaler().fit_transform(df2_trans) #normalizing data

# %%
matrix_values_normalized
# Out:
# array([[-0.58384998, -1.19020711, -1.2243021 , ..., -0.78023766,
#         -0.29407257, -0.2023557 ],
#        [-0.58398831, -0.72343218, -0.86952393, ..., -0.75420097,
#         -0.61815686, -0.55228699],
#        [-1.31619092, -0.49206794, -0.76036572, ..., -0.56389431,
#         -0.72257052, -1.31818888],
#        ...,
#        [-0.95152204, -0.57763018, -0.78641257, ..., -0.62829807,
#         -0.33862774, -1.0819212 ],
#        [-0.36449147, -1.3312222 , -1.00499794, ..., -0.44301343,
#         -0.48234814, -0.73787065],
#        [-0.30376779, -0.88261405, -0.3671323 , ..., -0.54587798,
#         -1.10932524, -1.71466089]])

# %% [markdown]
# A new dataframe can now be constructed with the transformed, normalized matrix values.

# %%
matrix_df = pd.DataFrame(matrix_values_normalized, columns=sample_names)

# %% [markdown]
# # PCA

# %% [markdown]
# a PCA plot shows correlation between variables, as well as sample clustering.

# %%
from sklearn.decomposition import PCA

pca = PCA()

pca_fit = pca.fit(matrix_values_normalized)

PC_values = np.arange(pca.n_components_) + 1

# %% [markdown]
# Most of variance can be explained by certain PCs. organizing and plotting all components first should provide how much it should be "cropped" by to find which PCs should be used in the analysis. This can be done using a dataframe and scree plot.

# %%
explained_var_ratio_df = pd.DataFrame( {'var_ratio': pca.explained_variance_ratio_, 'PC' : PC_values})

# %%
explained_var_ratio_df
# Out:
#     var_ratio  PC
# 0    0.516484   1
# 1    0.174129   2
# 2    0.065923   3
# 3    0.041529   4
# 4    0.030656   5
# ..        ...  ..
# 61   0.000610  62
# 62   0.000590  63
# 63   0.000587  64
# 64   0.000495  65
# 65   0.000444  66
#
# [66 rows x 2 columns]

# %% [markdown]
# PCs that are more than 5% responsible for variability are the ones that should be used. This happens to be PC1, PC2, and PC3. Let's double check this on a plot!

# %%
plt.figure(figsize=(4, 3), dpi=100)

PC_values = np.arange(pca.n_components_) + 1
plt.axvline(x=1,linestyle='--')
plt.axvline(x=2,linestyle='--')
plt.axvline(x=3,linestyle='--')
plt.plot(explained_var_ratio_df.loc[0:4, 'PC'], explained_var_ratio_df.loc[0:4, 'var_ratio'], 'o-', linewidth=2, color='blue')
plt.title('Scree Plot')
plt.xlabel('Principal Component')
plt.ylabel('Variance Explained')
plt.show()

# %% [markdown]
# After the first 3 PCs, it levels out significantly. PC1, PC2, and PC3 should be used when analyzing and plotting the data.

# %%
explained_var_ratio_df.loc[0:2, 'var_ratio'].values
# Out:
# array([0.51648366, 0.17412933, 0.06592322])

# %% [markdown]
# The variance can be explained by PC1, PC2 and PC3 approximately 51.6%, 17.4%, and 6.6% respectively.

# %% [markdown]
# Now to transpose and plot PCA

# %%
n_components_need = 3
pca_res1 = pd.DataFrame(np.transpose(pca_fit.components_[0:n_components_need, :]), columns=["PC" + str(x+1) for x in range(n_components_need)])
pca_res1["full_sample_name"] = sample_names

# %%
pca_res1
# Out:
#          PC1       PC2       PC3  \
# 0   0.133143 -0.008107 -0.077927
# 1   0.140654 -0.029207 -0.115974
# 2   0.134074 -0.051284 -0.142014
# 3   0.139046 -0.047830 -0.142234
# 4   0.134803 -0.073337 -0.133369
# ..       ...       ...       ...
# 61  0.141247  0.115110  0.018024
# 62  0.136799 -0.099606 -0.086157
# 63  0.135055 -0.123839 -0.049768
# 64  0.129014 -0.127906 -0.059142
# 65  0.123013 -0.126957 -0.042599
#
#                                      full_sample_name
# 0   C57BL/6_embryonic_facial_prominence_embryo_11....
# 1   C57BL/6_embryonic_facial_prominence_embryo_12....
# 2   C57BL/6_embryonic_facial_prominence_embryo_13....
# 3   C57BL/6_embryonic_facial_prominence_embryo_14....
# 4   C57BL/6_embryonic_facial_prominence_embryo_15....
# ..                                                ...
# 61               C57BL/6_neural_tube_embryo_15.5_days
# 62                   C57BL/6_stomach_embryo_14.5_days
# 63                   C57BL/6_stomach_embryo_15.5_days
# 64                   C57BL/6_stomach_embryo_16.5_days
# 65                   C57BL/6_stomach_postnatal_0_days
#
# [66 rows x 4 columns]

# %%
# the search tool is used to look at a sample name, sort out the tissue, day, and embryo vs postnatal

def get_tissue_n_days(sample_name):
    m=re.search("L/6_(\S+)_([^_]+)_days", str(sample_name))
    #print(sample_name + str(m))
    #print(m)
    tissue = None
    days = None
    if m:
        tissue = m.group(1)
        #sprint(tissue)
        days = m.group(2)
        #print(days)
    #print("\t".join([tissue, days]))
    
    tissue_pts = tissue.split("_")
    #print(tissue_pts[0:-1])
    tissue = "_".join(tissue_pts[0:-1])
    embryo_or_postnatal = tissue_pts[-1]
    
    return tissue, embryo_or_postnatal, days
  
    

embryo_n_days_info1 = pca_res1['full_sample_name'].apply(get_tissue_n_days)

# %%
embryo_n_days_info2 = pd.DataFrame(embryo_n_days_info1.tolist(), columns=['tissue', 'embryo_or_postnatal', 'days'])

# %% [markdown]
# Now these new columns can be added to a new dataframe!

# %%
pca_res2 = pd.concat([pca_res1, embryo_n_days_info2], axis=1)

# %%
pca_res2
# Out:
#          PC1       PC2       PC3  \
# 0   0.133143 -0.008107 -0.077927
# 1   0.140654 -0.029207 -0.115974
# 2   0.134074 -0.051284 -0.142014
# 3   0.139046 -0.047830 -0.142234
# 4   0.134803 -0.073337 -0.133369
# ..       ...       ...       ...
# 61  0.141247  0.115110  0.018024
# 62  0.136799 -0.099606 -0.086157
# 63  0.135055 -0.123839 -0.049768
# 64  0.129014 -0.127906 -0.059142
# 65  0.123013 -0.126957 -0.042599
#
#                                      full_sample_name  \
# 0   C57BL/6_embryonic_facial_prominence_embryo_11....
# 1   C57BL/6_embryonic_facial_prominence_embryo_12....
# 2   C57BL/6_embryonic_facial_prominence_embryo_13....
# 3   C57BL/6_embryonic_facial_prominence_embryo_14....
# 4   C57BL/6_embryonic_facial_prominence_embryo_15....
# ..                                                ...
# 61               C57BL/6_neural_tube_embryo_15.5_days
# 62                   C57BL/6_stomach_embryo_14.5_days
# 63                   C57BL/6_stomach_embryo_15.5_days
# 64                   C57BL/6_stomach_embryo_16.5_days
# 65                   C57BL/6_stomach_postnatal_0_days
#
#                          tissue embryo_or_postnatal  days
# 0   embryonic_facial_prominence              embryo  11.5
# 1   embryonic_facial_prominence              embryo  12.5
# 2   embryonic_facial_prominence              embryo  13.5
# 3   embryonic_facial_prominence              embryo  14.5
# 4   embryonic_facial_prominence              embryo  15.5
# ..                          ...                 ...   ...
# 61                  neural_tube              embryo  15.5
# 62                      stomach              embryo  14.5
# 63                      stomach              embryo  15.5
# 64                      stomach              embryo  16.5
# 65                      stomach           postnatal     0
#
# [66 rows x 7 columns]

# %% [markdown]
# Seaborn will be used to plot PCA.
#
# PC1 vs PC2 and PC2 vs PC3 will be plotted.

# %%
import seaborn as sns

PCA_plot = sns.relplot(data=pca_res2, x='PC1', y='PC2', hue='tissue', style='days', height = 8, s=200)

plt.title('2 component PCA', y=1, fontsize = 20)
PCA_plot.set(xlim=(-.01,.2),ylim=(-.17,.2))
plt.axhline(y=0,linestyle='--')
plt.axvline(x=0,linestyle='--')

PCA_plot

# %%
import seaborn as sns

PCA_plot = sns.relplot(data=pca_res2, x='PC2', y='PC3', hue='tissue', style='days', height = 8, s=200)

plt.title('2 component PCA', y=1, fontsize = 20)
PCA_plot.set(xlim=(-.2,.2),ylim=(-.2,.4))
plt.axhline(y=0,linestyle='--')
plt.axvline(x=0,linestyle='--')

PCA_plot

# %%
import seaborn as sns

fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(2,2,figsize=(20,15))
fig.suptitle('2 Component PCA', y=.92, x=.51, fontsize = 20)

PCA_plot1 = sns.scatterplot(data=pca_res2, x='PC1', y='PC2', hue='tissue', s=150, ax = ax1)
PCA_plot1.legend(fontsize = 8.5, loc = 'upper left')
PCA_plot1.set(xlim=(-.01,.2),ylim=(-.17,.2))
PCA_plot1.title.set_text('Tissue')
PCA_plot1.axhline(y=0,linestyle='--')
PCA_plot1.axvline(x=0,linestyle='--')
#plt.close()

PCA_plot2 = sns.scatterplot(data=pca_res2, x='PC1', y='PC2', style='days', s=150, ax = ax2)
PCA_plot2.legend(fontsize = 12, loc = 'upper right')
PCA_plot2.set(xlim=(-.01,.2),ylim=(-.17,.2))
PCA_plot2.title.set_text('Days')
PCA_plot2.axhline(y=0,linestyle='--')
PCA_plot2.axvline(x=0,linestyle='--')
#plt.close()

PCA_plot3 = sns.scatterplot(data=pca_res2, x='PC2', y='PC3', hue='tissue', s=150, ax = ax3)
PCA_plot3.legend(fontsize = 8.5, loc = 'upper right')
PCA_plot3.set(xlim=(-.2,.2),ylim=(-.2,.4))
PCA_plot3.title.set_text('Tissue')
PCA_plot3.axhline(y=0,linestyle='--')
PCA_plot3.axvline(x=0,linestyle='--')
#plt.close()

PCA_plot4 = sns.scatterplot(data=pca_res2, x='PC2', y='PC3', style='days', s=150, ax = ax4)
PCA_plot4.legend(fontsize = 12, loc = 'upper right')
PCA_plot4.set(xlim=(-.2,.2),ylim=(-.2,.4))
PCA_plot4.title.set_text('Days')
PCA_plot4.axhline(y=0,linestyle='--')
PCA_plot4.axvline(x=0,linestyle='--')
#plt.close()

# %% [markdown]
# PC1 vs PC2 seems to be more informative than PC2 vs PC3, with better clustering and more dispersion between clusters.

# %%
PCA_plot3 = sns.relplot(data=pca_res2, x="PC1", y="PC2", hue="tissue", col="tissue", style="days", col_wrap=3, s=200)

# %% [markdown]
# Now that the PCA has been plotted, t-SNE is next!

# %% [markdown]
# # t-SNE

# %% [markdown]
# t-SNE plots show the relationship between objects based on similarity of probability distributions.

# %% [markdown]
# A dataframe only containing the principal components of interest must be constructed as the input for t-SNE.

# %%
pca_values_3 = pca_res2[['PC1','PC2','PC3']]

# %%
from sklearn.manifold import TSNE

# random state is important in order to 'lock in' the plot / not lose the specific t-SNE plot generated.

tsne_app = TSNE(random_state = 213, perplexity = 10)
tsne_res1 = tsne_app.fit_transform(pca_values_3.values)
# Out:
# /usr/local/Caskroom/miniforge/base/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/Caskroom/miniforge/base/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
tsne_data = pd.DataFrame(tsne_res1.tolist(), columns=['tSNE1','tSNE2']) #creating a df with t-SNE outputs

# %%
tsne_df = pd.concat([pca_res2, tsne_data], axis=1) #adding the t-SNE data to the overall df

# %%
tsne_df
# Out:
#          PC1       PC2       PC3  \
# 0   0.133143 -0.008107 -0.077927
# 1   0.140654 -0.029207 -0.115974
# 2   0.134074 -0.051284 -0.142014
# 3   0.139046 -0.047830 -0.142234
# 4   0.134803 -0.073337 -0.133369
# ..       ...       ...       ...
# 61  0.141247  0.115110  0.018024
# 62  0.136799 -0.099606 -0.086157
# 63  0.135055 -0.123839 -0.049768
# 64  0.129014 -0.127906 -0.059142
# 65  0.123013 -0.126957 -0.042599
#
#                                      full_sample_name  \
# 0   C57BL/6_embryonic_facial_prominence_embryo_11....
# 1   C57BL/6_embryonic_facial_prominence_embryo_12....
# 2   C57BL/6_embryonic_facial_prominence_embryo_13....
# 3   C57BL/6_embryonic_facial_prominence_embryo_14....
# 4   C57BL/6_embryonic_facial_prominence_embryo_15....
# ..                                                ...
# 61               C57BL/6_neural_tube_embryo_15.5_days
# 62                   C57BL/6_stomach_embryo_14.5_days
# 63                   C57BL/6_stomach_embryo_15.5_days
# 64                   C57BL/6_stomach_embryo_16.5_days
# 65                   C57BL/6_stomach_postnatal_0_days
#
#                          tissue embryo_or_postnatal  days      tSNE1  \
# 0   embryonic_facial_prominence              embryo  11.5   0.742468
# 1   embryonic_facial_prominence              embryo  12.5   0.547598
# 2   embryonic_facial_prominence              embryo  13.5   3.561448
# 3   embryonic_facial_prominence              embryo  14.5   4.997335
# 4   embryonic_facial_prominence              embryo  15.5   2.605098
# ..                          ...                 ...   ...        ...
# 61                  neural_tube              embryo  15.5 -14.337314
# 62                      stomach              embryo  14.5  15.692097
# 63                      stomach              embryo  15.5  21.520935
# 64                      stomach              embryo  16.5  19.574600
# 65                      stomach           postnatal     0  21.149237
#
#         tSNE2
# 0   72.916855
# 1   69.957092
# 2   66.245392
# 3   68.436394
# 4   63.675751
# ..        ...
# 61 -60.161816
# 62  47.928730
# 63  37.480465
# 64  39.048187
# 65  34.270725
#
# [66 rows x 9 columns]

# %%
tSNE_plot = sns.relplot(data=tsne_df, x='tSNE1', y='tSNE2', hue='tissue', style='days', height = 10, s=150)

plt.title('t-SNE Plot', y=1, fontsize = 20)
plt.axhline(y=0,linestyle='--')
plt.axvline(x=0,linestyle='--')

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(20,10))
fig.suptitle('t-SNE Plots', y=.95, x=.5, fontsize = 20)

tSNE_plot1 = sns.scatterplot(data=tsne_df, x='tSNE1', y='tSNE2', hue='tissue', s=150, ax = ax1)
tSNE_plot1.legend(fontsize = 12, loc = 'upper left')
tSNE_plot1.set(xlim=(-60,60),ylim=(-90,90))
tSNE_plot1.title.set_text('Tissue')
tSNE_plot1.axhline(y=0,linestyle='--')
tSNE_plot1.axvline(x=0,linestyle='--')
#plt.close()

tSNE_plot2 = sns.scatterplot(data=tsne_df, x='tSNE1', y='tSNE2', style='days', s=150, ax = ax2)
tSNE_plot2.legend(fontsize = 15, loc = 'upper left')
tSNE_plot2.set(xlim=(-60,60),ylim=(-90,90))
tSNE_plot2.title.set_text('Days')
tSNE_plot2.axhline(y=0,linestyle='--')
tSNE_plot2.axvline(x=0,linestyle='--')
#plt.close()

# %%
tSNE_plot3 = sns.relplot(data=tsne_df, x="tSNE1", y="tSNE2", hue="tissue", col="tissue", style="days", col_wrap=3, s=200)

# %% [markdown]
# Finally (last, but not least) UMAP!

# %% [markdown]
# # UMAP

# %% [markdown]
# A UMAP plot shows how likely two objects are connected / correlated.

# %%
import umap

reducer = umap.UMAP()

umap_res1 = reducer.fit_transform(pca_values_3)

# %%
umap_data = pd.DataFrame(umap_res1.tolist(), columns=['UMAP1','UMAP2']) #creating a df with UMAP outputs

# %%
umap_df = pd.concat([tsne_df, umap_data], axis=1) #adding the UMAP data to the overall df

# %%
UMAP_plot = sns.relplot(data=umap_df, x='UMAP1', y='UMAP2', hue='tissue', style='days', height = 6, s=100)

plt.title('UMAP Plot', y=1, fontsize = 20)
# Out:
# Text(0.5, 1, 'UMAP Plot')

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(20,10))
fig.suptitle('UMAP Plots', y=.95, x=.5, fontsize = 20)

UMAP_plot1 = sns.scatterplot(data=umap_df, x='UMAP1', y='UMAP2', hue='tissue', s=150, ax = ax1)
UMAP_plot1.legend(fontsize = 10, loc = 'upper left')
UMAP_plot1.set(xlim=(-10,30),ylim=(-5,25))
UMAP_plot1.title.set_text('Tissue')
#plt.close()

UMAP_plot2 = sns.scatterplot(data=umap_df, x='UMAP1', y='UMAP2', style='days', s=150, ax = ax2)
UMAP_plot2.legend(fontsize = 15, loc = 'upper left')
UMAP_plot2.set(xlim=(-10,30),ylim=(-5,25))
UMAP_plot2.title.set_text('Days')
#plt.close()

# %%
UMAP_plot3 = sns.relplot(data=umap_df, x="UMAP1", y="UMAP2", hue="tissue", col="tissue", style="days", col_wrap=3, s=200)

# %%
#PCA_plot3.savefig("PCA_facet.jpg")
#tSNE_plot3.savefig("tSNE_facet.jpg")
#UMAP_plot3.savefig("UMAP_facet.jpg")
